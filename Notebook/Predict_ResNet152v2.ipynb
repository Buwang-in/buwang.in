# %%
import numpy as np
from PIL import Image
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model
from tensorflow.keras.applications import ResNet152V2
from tensorflow.keras.applications.resnet_v2 import preprocess_input

# %%
# Fungsi untuk memprediksi kelas gambar
def predict_image(image_path):
    # Mengubah gambar menjadi format yang dapat diproses oleh model
    image_width = 300
    image_height = 300
    img = image.load_img(image_path, target_size=(image_width, image_height))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    processed_img = preprocess_input(img_array)
    class_labels = ['Kardus', 'Kaca (White & Green)', 'Plastik', 'Kertas', 'Logam', 'Organik', 'Botol Plastik', 'Botol Kaca']

    # Melakukan prediksi dengan model
    prediction = model.predict(processed_img)
    predicted_class = np.argmax(prediction)

    # Mengembalikan hasil prediksi
    return class_labels[predicted_class]

# %%
# Mengunggah gambar
from google.colab import files
uploaded_image = files.upload()
uploaded_image_path = list(uploaded_image.keys())[0]
img = Image.open(uploaded_image_path)
img.show()
# Out:
#      <input type="file" id="files-b1bf3ad6-14b2-41d8-8a53-41a727f47038" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b1bf3ad6-14b2-41d8-8a53-41a727f47038">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Memuat model
from google.colab import drive
drive.mount('/content/drive')
model = load_model('/content/drive/Shared drives/CAPSTONE C23-PS061/Model/ResNet152V2_Akurasi.h5')  # Ganti dengan path model yang Anda ingin gunakan
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Memanggil fungsi prediksi dan menampilkan hasil
predicted_class = predict_image(uploaded_image_path)
print(f'Predicted class: {predicted_class}')
# Out:
# 1/1 [==============================] - 3s 3s/step
# Predicted class: Logam
